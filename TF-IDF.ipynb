# %% [markdown]
# # TF-IDF Vectors

# %% [markdown]
# ### We obtain the tf-idf vectors from a set of 600,000 samples.

# %%
import pandas as pd
import spacy
import re
import scipy
import unidecode
import warnings
import numpy as np
import sys

warnings.filterwarnings('ignore')

# %% [markdown]
# #### StopWords Portugues

# %%
spacy_nlp = spacy.load('pt')
spacy_stopwords = spacy.lang.pt.STOP_WORDS

# %% [markdown]
# #### Stematize Function
#
# RSLPStemmer use portugues dictionary

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem import RSLPStemmer
#>>>st = RSLPStemmer()
class SteamTokenizer(object):
    def __init__(self):
        self.wnl = RSLPStemmer()
    def __call__(self, doc):
        return [self.wnl.stem(t) for t in word_tokenize(doc)]

# %%
#nltk.download('rslp')

# %%
data = pd.read_csv("products.csv",encoding='latin')

# %%
data.shape
# Out:
# (674719, 10)

# %%
data.head()
# Out:
#    ID_PDC                               ESPECIALIDADE  \
# 0  174274       SISTEMA GENITAL E REPRODUTOR FEMININO
# 1  176721  SISTEMA MUSCULO-ESQUELETICO E ARTICULAÇÕES
# 2  181909             METODOS DIAGNOSTICOS POR IMAGEM
# 3  183381                  SISTEMA DIGESTIVO E ANEXOS
# 4  183381                  SISTEMA DIGESTIVO E ANEXOS
#
#                               PROCEDIMENTO_PRINCIPAL  \
# 0  HISTERECTOMIA TOTAL LAPAROSCOPICA COM ANEXECTO...
# 1  LESÃO  AGUDA DE LIGAMENTO COLATERAL DO JOELHO ...
# 2  EMBOLIZAÇÃO DE ANEURISMA CEREBRAL POR OCLUSÃO ...
# 3  PANCREATO-DUODENECTOMIA COM LINFADENECTOMIA [ ...
# 4  PANCREATO-DUODENECTOMIA COM LINFADENECTOMIA [ ...
#
#                                 DESCRICAO_DO_PRODUTO       ANVISA  \
# 0                  MANIPULADOR UTERINO CLEARVIEW 7CM  80517980053
# 1  ENXERTO OSSEO EM BLOCO 6 CC 2 X 3 CC ATTRAX PUTTY  80074640024
# 2                         INTRODUTOR 6F 12CM ULTIMUM  10332340107
# 3                                PINÇA LIGA SURE 5MM  10349000188
# 4                    TROCATER DESCARTAVEL 12.5X100MM  80082910071
#
#                   MARCA REFERENCIA    PRECO  \
# 0  CLINICAL INNOVATIONS      UM700     9625
# 1              NUVASIVE    5018006     6875
# 2               ST JUDE     407694     1375
# 3             VALLEYLAB     LS1500  33687.5
# 4  HANGZHOU KANGJI MEDI    101Y524   2062.5
#
#                                           ANVISA_DEF  \
# 0                                                  -
# 1                 attrax putty nuvasive nuvasive inc
# 2                                                  -
# 3                                                  -
# 4  trocarter descartavel hangzhou kangji medical ...
#
#                            GMDN_TERMO
# 0     uterine manipulator, single-use
# 1      bone matrix implant, synthetic
# 2  vascular catheter introduction set
# 3                                   -
# 4                                   -

# %% [markdown]
# ##### Preprocess data

# %%
data["DOCS"] = data["PROCEDIMENTO_PRINCIPAL"] + " " + data["DESCRICAO_DO_PRODUTO"]

# %%
data["DOCS"] = data["DOCS"].apply(lambda x : x.lower() )
data["DOCS"] = data["DOCS"].apply(lambda x : re.sub("[^a-zA-ZÀ-ú']+",' ',x) )
data["DOCS"] = data["DOCS"].apply(lambda x : unidecode.unidecode(x) )

# %%
data["DOCS"].head()
# Out:
# 0    histerectomia total laparoscopica com anexecto...
# 1    lesao aguda de ligamento colateral do joelho t...
# 2    embolizacao de aneurisma cerebral por oclusao ...
# 3    pancreato duodenectomia com linfadenectomia pa...
# 4    pancreato duodenectomia com linfadenectomia pa...
# Name: DOCS, dtype: object

# %% [markdown]
# #### Vocabulary of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
docs = data["DOCS"].tolist()

# %%
#create a vocabulary of words, 
#ignore words that appear in 85% of documents, 
#eliminate stop words
CV = CountVectorizer(max_df=0.85,stop_words=spacy_stopwords,lowercase=True,tokenizer=SteamTokenizer())

# %%
word_count_vector = CV.fit_transform(docs)

# %%
CV.vocabulary_
# Out:
# {'histerectom': 3194,
#  'total': 6746,
#  'laparoscop': 3728,
#  'anexectom': 301,
#  'bilater': 730,
#  'uter': 7137,
#  'manipul': 3987,
#  'uterin': 7138,
#  'clearview': 1284,
#  'lesa': 3786,
#  'agud': 184,
#  'colater': 1341,
#  'joelh': 3627,
#  'trat': 6866,
#  'cirurg': 1241,
#  'reconstruca': 5617,
#  'titani': 6694,
#  'interferenc': 3476,
#  'traumed': 6876,
#  'enxert': 2293,
#  'osse': 4739,
#  'bloc': 849,
#  'attrax': 554,
#  'putty': 5466,
#  'embolizaca': 2139,
#  'aneurism': 298,
#  'cerebr': 1161,
#  'oclusa': 4617,
#  'sacul': 5912,
#  'metod': 4159,
#  'interven': 3503,
#  'terapeu': 6594,
#  'imag': 3282,
#  'introdu': 3560,
#  'ultimum': 7024,
#  'pancreat': 4834,
#  'duodenectom': 2021,
#  'linfadenectom': 3838,
#  'pancre': 4832,
#  'pinc': 5104,
#  'trocat': 6944,
#  'descarta': 1810,
#  'simpatectom': 6099,
#  'videotoracoscop': 7286,
#  'nerv': 4480,
#  'perifer': 5014,
#  'dissec': 1945,
#  'ganch': 2875,
#  'angioplast': 315,
#  'translum': 6812,
#  'percutane': 4983,
#  'multipl': 4385,
#  'impl': 3297,
#  'stent': 6322,
#  'hemodinam': 3093,
#  'cardiolog': 1060,
#  'proced': 5325,
#  'floppy': 2763,
#  'sistem': 6137,
#  'derivaca': 1795,
#  'ventricul': 7214,
#  'intern': 3493,
#  'valvul': 7154,
#  'reviso': 5803,
#  'encefal': 2161,
#  'regula': 5663,
#  'apendicectom': 377,
#  'videolaparoscop': 7283,
#  'intestin': 3509,
#  'grampe': 2974,
#  'echelon': 2064,
#  'articul': 465,
#  'liberaca': 3797,
#  'aderenc': 124,
#  'pelv': 4959,
#  'ressecca': 5728,
#  'cist': 1248,
#  'peritone': 5027,
#  'salpingolis': 5928,
#  'cavidad': 1115,
#  'pared': 4887,
#  'agulh': 187,
#  'veres': 7227,
#  'irrig': 3596,
#  'aspir': 504,
#  'desfibril': 1825,
#  'plac': 5120,
#  'eletrod': 2101,
#  'marc': 4001,
#  'pass': 4909,
#  'retir': 5757,
#  'parafus': 4860,
#  'hast': 3043,
#  'metal': 4149,
#  'intr': 3511,
#  'mater': 4036,
#  'sintes': 6125,
#  'schanz': 5956,
#  'gramp': 2973,
#  'correca': 1574,
#  'deform': 1764,
#  'resolut': 5719,
#  'integrity': 3445,
#  'pleurectom': 5149,
#  'pleur': 5148,
#  'catet': 1102,
#  'bloquei': 861,
#  'endobronqu': 2181,
#  'lobectom': 3879,
#  'hepa': 3113,
#  'esquerd': 2425,
#  'bili': 732,
#  'trocart': 6943,
#  'xcel': 7382,
#  'lamin': 3713,
#  'teso': 6614,
#  'ultracision': 7030,
#  'harmonic': 3040,
#  'line': 3832,
#  'cort': 1579,
#  'cateter': 1103,
#  'cardiac': 1055,
#  'cineangiocoronariograf': 1219,
#  'ventriculograf': 7217,
#  'diagnost': 1862,
#  'dren': 1999,
#  'multiv': 4397,
#  'pressa': 5295,
#  'conexa': 1463,
#  'mach': 3930,
#  'feme': 2660,
#  'angiograf': 309,
#  'pleuroscop': 5152,
#  'vide': 7276,
#  'retra': 5766,
#  'incisa': 3328,
#  'small': 6164,
#  'colectom': 1349,
#  'parc': 4882,
#  'colostom': 1375,
#  'carg': 1075,
#  'endoscop': 2224,
#  'prostat': 5386,
#  'vesicul': 7257,
#  'maquin': 3999,
#  'dupl': 2027,
#  'azul': 623,
#  'frat': 2832,
#  'femur': 2665,
#  'calibr': 998,
#  'sele': 5995,
#  'grand': 2976,
#  'angiorradiolog': 317,
#  'angul': 323,
#  'bandej': 655,
#  'microesf': 4194,
#  'embozen': 2148,
#  'microm': 4202,
#  'vermelh': 7228,
#  'intracrani': 3522,
#  'parenquem': 4889,
#  'monitorizaca': 4314,
#  'bipol': 822,
#  'forcep': 2800,
#  'endometrios': 2205,
#  'versaport': 7244,
#  'craniotom': 1630,
#  'descompress': 1817,
#  'crani': 1619,
#  'silicon': 6082,
#  'microdissecca': 4191,
#  'luxaco': 3925,
#  'nivel': 4552,
#  'tornozel': 6735,
#  'cortic': 1582,
#  'esponj': 2415,
#  'rosc': 5853,
#  'matriz': 4045,
#  'regeneraca': 5654,
#  'dural': 2035,
#  'durepa': 2045,
#  'fibrin': 2686,
#  'evicel': 2514,
#  'aplic': 384,
#  'luxaca': 3924,
#  'avulsa': 612,
#  'femor': 2663,
#  'articulaca': 467,
#  'hidrofil': 3152,
#  'standart': 6297,
#  'proteca': 5397,
#  'emboshied': 2143,
#  'hitorqu': 3199,
#  'versacor': 7238,
#  'pseudartros': 5421,
#  'artros': 489,
#  'extern': 2581,
#  'dinam': 1901,
#  'onix': 4652,
#  'prostatavesiculectom': 5387,
#  'radic': 5517,
#  'succa': 6390,
#  'incomep': 3340,
#  'hern': 3124,
#  'disc': 1925,
#  'torac': 6717,
#  'lomb': 3890,
#  'colun': 1388,
#  'vertebr': 7249,
#  'agent': 170,
#  'hemosta': 3105,
#  'colagen': 1337,
#  'absorvi': 35,
#  'heliten': 3067,
#  'instalaca': 3428,
#  'circuit': 1232,
#  'circulaca': 1234,
#  'extracorpore': 2590,
#  'convenc': 1525,
#  'outr': 4791,
#  'conjunt': 1486,
#  'adult': 142,
#  'ecobec': 2067,
#  'hemoconcentr': 3088,
#  'mediast': 4079,
#  'bomb': 881,
#  'centrifug': 1150,
#  'centriflux': 1149,
#  'canul': 1026,
#  'aram': 418,
#  'coronari': 1562,
#  'bala': 638,
#  'concomit': 1445,
#  'omeg': 4640,
#  'anacond': 273,
#  'terum': 6611,
#  'pont': 5222,
#  'ultr': 7026,
#  'stiff': 6332,
#  'inoxida': 3410,
#  'revest': 5798,
#  'revascularizaca': 5792,
#  'miocardi': 4270,
#  'coronariopat': 1564,
#  'cardiopleg': 1067,
#  'colangiopancreatograf': 1340,
#  'retrogr': 5778,
#  'papilotm': 4848,
#  'tripl': 6929,
#  'lumen': 3915,
#  'artroplast': 487,
#  'escapul': 2357,
#  'umer': 7051,
#  'cint': 1226,
#  'arrow': 447,
#  'camis': 1007,
#  'membr': 4108,
#  'polietersulf': 5194,
#  'flux': 2782,
#  'retropleg': 5783,
#  'insufl': 3438,
#  'encor': 2168,
#  'advantag': 149,
#  'suport': 6420,
#  'choic': 1191,
#  'apex': 379,
#  'bicamer': 709,
#  'punca': 5450,
#  'peel': 4950,
#  'away': 614,
#  'dilock': 1895,
#  'qualqu': 5485,
#  'tecn': 6545,
#  'versa': 7236,
#  'quadril': 5480,
#  'restri': 5741,
#  'ciment': 1211,
#  'epimiocardi': 2317,
#  'temporari': 6564,
#  'patch': 4915,
#  'pericardi': 5006,
#  'bovin': 904,
#  'curv': 1699,
#  'glid': 2944,
#  'colocaca': 1368,
#  'protes': 5401,
#  'coledoci': 1351,
#  'dilat': 1890,
#  'sbdc': 5947,
#  'jagw': 3617,
#  'papilot': 4847,
#  'retencion': 5753,
#  'reforc': 5649,
#  'cruz': 1675,
#  'anteri': 344,
#  'posteri': 5248,
#  'videoartroscop': 7277,
#  'bioscrew': 804,
#  'elevat': 2111,
#  'disposi': 1940,
#  'repar': 5699,
#  'prolaps': 5364,
#  'apic': 380,
#  'fixaca': 2723,
#  'nefrectom': 4449,
#  'unilater': 7077,
#  'bacinet': 630,
#  'supr': 6423,
#  'renal': 5690,
#  'sutur': 6463,
#  'sinte': 6123,
#  'verd': 7226,
#  'vloc': 7321,
#  'ureterorrenolitotrips': 7113,
#  'uret': 7096,
#  'espir': 2406,
#  'nitinol': 4547,
#  'retenca': 5752,
#  'resgat': 5714,
#  'urolog': 7130,
#  'ston': 6338,
#  'diges': 1884,
#  'biops': 792,
#  'citolog': 1265,
#  'colangi': 1338,
#  'standard': 6296,
#  'contour': 1516,
#  'ureteroscop': 7114,
#  'sensor': 6018,
#  'angiog': 308,
#  'ultimat': 7023,
#  'leso': 3789,
#  'intrinsec': 3558,
#  'condr': 1453,
#  'osteocondrit': 4749,
#  'plic': 5156,
#  'patolog': 4922,
#  'corp': 1566,
#  'livr': 3875,
#  'artrofitos': 484,
#  'shav': 6054,
#  'nucle': 4572,
#  'point': 5179,
#  'simmom': 6093,
#  'pigtail': 5095,
#  'amplatz': 262,
#  'short': 6069,
#  'long': 3894,
#  'radiofocu': 5525,
#  'introduc': 3561,
#  'tromb': 6948,
#  'mandibul': 3975,
#  'func': 2856,
#  'broc': 931,
#  'medic': 4084,
#  'odontolog': 4627,
#  'grau': 2987,
#  'nefrolitotrips': 4451,
#  'indovasiv': 3354,
#  'compon': 1415,
#  'acetabul': 66,
#  'century': 1154,
#  'modul': 4304,
#  'cimentaca': 1212,
#  'angi': 302,
#  'seal': 5968,
#  'associ': 515,
#  'menisc': 4117,
#  'endobotton': 2179,
#  'espec': 2397,
#  'plas': 5129,
#  'mont': 4332,
#  'flex': 2745,
#  'runway': 5895,
#  'eluica': 2130,
#  'everolimu': 2513,
#  'promu': 5372,
#  'element': 2093,
#  'complac': 1408,
#  'quantum': 5487,
#  'sinusectom': 6130,
#  'maxil': 4056,
#  'endonas': 2209,
#  'paranas': 4876,
#  'bleed': 842,
#  'basket': 677,
#  'extraca': 2587,
#  'calcul': 994,
#  'insert': 3421,
#  'revisa': 5801,
#  'nefrolitotom': 4450,
#  'artrodes': 480,
#  'poster': 5247,
#  'later': 3757,
#  'cervic': 1167,
#  'cercl': 1159,
#  'inclu': 3334,
#  'descol': 1816,
#  'epifisari': 2308,
#  'cotovel': 1597,
#  'punh': 5454,
#  'antebrac': 337,
#  'gastroplast': 2891,
#  'obes': 4591,
#  'morb': 4336,
#  'estomag': 2472,
#  'osteotom': 4775,
#  'rosq': 5856,
#  'vapr': 7163,
#  'mastectom': 4028,
#  'subcutane': 6367,
#  'inclusa': 3336,
#  'text': 6619,
#  'redond': 5630,
#  'perfil': 4990,
#  'fixation': 2726,
#  'stapl': 6298,
#  'medi': 4078,
#  'brac': 907,
#  'retossigmoidectom': 5763,
#  'abdom': 9,
#  'circul': 1233,
#  'transrad': 6837,
#  'osteoplast': 4766,
#  'prognat': 5351,
#  'micrognat': 4198,
#  'laterognat': 3758,
#  'cran': 1616,
#  'format': 2804,
#  'rosque': 5858,
#  'cabec': 978,
#  'diametr': 1874,
#  'comp': 1398,
#  'estabiliz': 2434,
#  'bimaxil': 736,
#  'bloque': 857,
#  'shunt': 6071,
#  'intracardiac': 3513,
#  'assist': 512,
#  'contrat': 1521,
#  'adrenalectom': 139,
#  'clip': 1293,
#  'hemolok': 3096,
#  'univers': 7090,
#  'pielograf': 5081,
#  'orient': 4697,
#  'colangiograf': 1339,
#  'transcutane': 6776,
#  'accustick': 55,
#  'carp': 1082,
#  'plug': 5160,
#  'intramedul': 3532,
#  'delt': 1780,
#  'uniqu': 7086,
#  'ventilaca': 7208,
#  'perfuraca': 4998,
#  'conec': 1459,
#  'plan': 5123,
#  'valg': 7146,
#  'versalock': 7241,
#  'centr': 1145,
#  'hemodepuraca': 3090,
#  'infusa': 3385,
#  'drog': 2007,
#  'acess': 61,
#  'vascul': 7179,
#  'picc': 5076,
#  'cath': 1107,
#  'polipectom': 5201,
#  'oval': 4792,
#  'frasc': 2831,
#  'gastr': 2884,
#  'drain': 1995,
#  'simon': 6095,
#  'sprint': 6278,
#  'laparotom': 3730,
#  'explor': 2566,
#  'abscess': 28,
#  'brid': 925,
#  'vigenc': 7289,
#  'uretrotom': 7124,
#  'uretr': 7120,
#  'manquit': 3993,
#  'hyperform': 3250,
#  'cobr': 1317,
#  'colonoscop': 1370,
#  'retossigmoidoscop': 5764,
#  'artroscop': 491,
#  'diret': 1918,
#  'ureter': 7097,
#  'ligad': 3808,
#  'tireoidectom': 6678,
#  'tireoid': 6676,
#  'sond': 6217,
#  'eletroest': 2103,
#  'herniorraf': 3128,
#  'ingu': 3388,
#  'polipropilen': 5202,
#  'prolen': 5365,
#  'reperfusa': 5701,
#  'aspiraca': 505,
#  'microcirurg': 4181,
#  'raney': 5545,
#  'pacot': 4810,
#  'unidad': 7067,
#  'duragen': 2034,
#  'comum': 1433,
#  'epid': 2303,
#  'temperat': 6561,
#  'neurodur': 4493,
#  'inox': 3409,
#  'testicul': 6617,
#  'permanenc': 5035,
#  'aplit': 388,
#  'antibio': 350,
#  'lineag': 3833,
#  'instrumentaca': 3434,
#  'segment': 5985,
#  'pedicul': 4942,
#  'poliax': 5186,
#  'spherx': 6251,
#  'beir': 690,
#  'leit': 3777,
#  'swan': 6472,
#  'ganz': 2879,
#  'debit': 1737,
#  'continu': 1513,
#  'flotrac': 2766,
#  'fibul': 2689,
#  'pern': 5040,
#  'troc': 6938,
#  'dilataca': 1891,
#  'wireguided': 7372,
#  'tumor': 6990,
#  'micr': 4170,
#  'fres': 2843,
#  'carniot': 1078,
#  'blak': 836,
#  'cilindr': 1210,
#  'compress': 1428,
#  'neurocirurg': 4490,
#  'spong': 6271,
#  'parenquim': 4890,
#  'tuneliz': 6995,
#  'sophys': 6230,
#  'adheru': 127,
#  'avulso': 613,
#  'fiogu': 2705,
#  'oliv': 4635,
#  'inorgan': 3406,
#  'inorg': 3405,
#  'hemodialis': 3091,
#  'curt': 1696,
#  'extrem': 2596,
#  'metafis': 4145,
#  'dist': 1951,
#  'radi': 5515,
#  'bols': 879,
#  'hematom': 3073,
#  'impact': 3288,
#  'coxofemor': 1608,
#  'reservatori': 5711,
#  'filtr': 2701,
#  'arter': 450,
#  'absorv': 34,
#  'surgidry': 6447,
#  'valv': 7151,
#  'velud': 7200,
#  'optitorqu': 4685,
#  'intralum': 3531,
#  'direit': 1914,
#  'transesfenoid': 6786,
#  'sonic': 6218,
#  'sonoc': 6222,
#  'hydrogel': 3242,
#  'impermeabilizaca': 3295,
#  'duramat': 2037,
#  'durase': 2040,
#  'clavicul': 1276,
#  'ombr': 4639,
#  'acromioniz': 91,
#  'aort': 368,
#  'infr': 3379,
#  'equaliz': 2329,
#  'endoprotes': 2219,
#  'extensa': 2576,
#  'flexi': 2750,
#  'inje': 3393,
#  'escleros': 2363,
#  'variz': 7174,
#  'primari': 5313,
#  'farmacolog': 2638,
#  'plast': 5134,
#  'valvoplast': 7153,
#  'oxigen': 4797,
#  'cpc': 1611,
#  'offset': 4629,
#  'tampa': 6509,
#  'interfit': 3477,
#  'reflection': 5644,
#  'lindorf': 3830,
#  'shaft': 6049,
#  'glidew': 2947,
#  'estud': 2485,
#  'cardiopat': 1064,
#  'congenit': 1476,
#  'valvopat': 7152,
#  'cinecoronariograf': 1223,
#  'oximetr': 4800,
#  'impuls': 3317,
#  'launch': 3761,
#  'sang': 5932,
#  'cardiotom': 1069,
#  'pediatr': 4939,
#  'asplas': 509,
#  'camp': 1008,
#  'opsit': 4669,
#  'gram': 2972,
#  'titane': 6691,
#  'eurocon': 2498,
#  'ceram': 1156,
#  'biolox': 771,
#  'fort': 2808,
#  'estimulaca': 2469,
#  'ingevity': 3387,
#  'estenostom': 2449,
#  'histeroscop': 3196,
#  'ressectoscopi': 5729,
#  'miomectom': 4273,
#  'metroplast': 4161,
#  'endometrectom': 2203,
#  'sinequ': 6109,
#  'ultrasson': 7042,
#  'coagulaca': 1304,
#  'compr': 1425,
#  'sonosurg': 6225,
#  'extrac': 2586,
#  'remoca': 5684,
#  'forc': 2799,
#  'intravascul': 3552,
#  'pulmon': 5443,
#  'reduca': 5633,
#  'incruent': 3346,
#  'cest': 1171,
#  'extra': 2585,
#  'segur': 5989,
#  'hemisph': 3083,
#  'kirshin': 3677,
#  'falang': 2620,
#  'metacarpi': 4139,
#  'parcu': 4884,
#  'ablaca': 20,
#  'bipas': 819,
#  'mastoidectom': 4032,
#  'simpl': 6100,
#  'modific': 4302,
#  'orelh': 4694,
#  'contat': 1505,
#  'dermolipectom': 1800,
#  'avent': 601,
#  'export': 2568,
#  'axil': 616,
#  'poplite': 5224,
#  'wall': 7345,
#  'interfalange': 3471,
#  'light': 3816,
#  'ortoped': 4728,
#  'membrana': 4109,
#  'vacu': 7141,
#  'labr': 3701,
#  'microdebridaca': 4186,
#  'incis': 3327,
#  'ster': 6325,
#  'drap': 1996,
#  'sonicision': 6220,
#  'chav': 1181,
#  'torqu': 6740,
#  'hallux': 3028,
#  'valgu': 7147,
#  'fend': 2666,
#  'eletrofisiolog': 2106,
#  'mape': 3997,
#  'eletr': 2094,
#  'eletron': 2108,
#  'tridimens': 6907,
#  'conduca': 1456,
#  'aca': 39,
#  'steerocath': 6315,
#  'radifocu': 5520,
#  'focu': 2786,
#  'gastrectom': 2885,
#  'seri': 6032,
#  'operatori': 4663,
#  'drenoplas': 2001,
#  'etmo': 2491,
#  'orbit': 4691,
#  'etmoid': 2492,
#  'traum': 6872,
#  'maxdriv': 4051,
#  'acraclip': 81,
#  'lightwav': 3817,
#  'segmentectom': 5987,
#  'pulma': 5442,
#  'recarg': 5597,
#  'dour': 1992,
#  'gastrostom': 2893,
#  'botton': 901,
#  'alimentaca': 210,
#  'enter': 2266,
#  'arruel': 448,
#  'dent': 1786,
#  'monoax': 4317,
#  'rotur': 5879,
#  'desinserca': 1834,
#  'arranc': 436,
#  'capsul': 1034,
#  'ligament': 3810,
#  'distraca': 1958,
#  'catch': 1100,
#  'ligasur': 3814,
#  'maryland': 4023,
#  'bainh': 635,
#  'port': 5234,
#  'interlock': 3482,
#  'fibr': 2681,
#  'medikit': 4088,
#  'highflex': 3163,
#  'tenotom': 6590,
#  'tendo': 6574,
#  'burs': 971,
#  'sinov': 6118,
#  'coarctaca': 1308,
#  'defeit': 1753,
#  'estagi': 2437,
#  'trapezoid': 6856,
#  'polietilen': 5195,
#  'profemur': 5340,
#  'razek': 5566,
#  'puls': 5444,
#  'safi': 5919,
#  'promr': 5371,
#  'marcapass': 4003,
#  'condic': 1448,
#  'ressonanc': 5732,
#  'magne': 3949,
#  'etrins': 2495,
#  'punch': 5452,
#  'trilogy': 6921,
#  'driv': 2006,
#  'bent': 697,
#  'cros': 1656,
#  'cefal': 1126,
#  'optilit': 4679,
#  'unic': 7062,
#  'lotu': 3908,
#  'prelud': 5279,
#  'colecistectom': 1345,
#  'capac': 1028,
#  'trabalh': 6752,
#  'ench': 2165,
#  'confecca': 1466,
#  'fistul': 2716,
#  'endoscopi': 2225,
#  'osteocondroplast': 4750,
#  'estabilizaca': 2435,
#  'acromioplast': 92,
#  'decapol': 1746,
#  'cartuch': 1092,
#  'evercros': 2509,
#  'retard': 5750,
#  'consolidaca': 1494,
#  'perd': 4985,
#  'conic': 1479,
#  'marlex': 4012,
#  'biolog': 770,
#  'intraor': 3540,
#  'serr': 6034,
#  'reciproc': 5605,
#  'soehendr': 6187,
#  'meniscectom': 4118,
#  'arthrocut': 459,
#  'full': 2853,
#  'smith': 6174,
#  'nephew': 4475,
#  'bioabsorvi': 740,
#  'hidroxiapatit': 3160,
#  'conserv': 1491,
#  'bloq': 854,
#  'vital': 7310,
#  'pequen': 4973,
#  'monocamer': 4319,
#  'instrument': 3433,
#  'esofag': 2384,
#  'duoden': 2020,
#  'sering': 6033,
#  'insuflaca': 3439,
#  'especific': 2399,
#  'esfer': 2376,
#  'sinovectom': 6120,
#  'subtot': 6387,
#  'reimpl': 5665,
#  'extr': 2584,
#  'intravesic': 3555,
#  'injeca': 3394,
#  'glen': 2940,
#  'obtur': 4603,
#  'trac': 6756,
#  'anestes': 296,
#  'simpa': 6096,
#  'estimul': 2468,
#  'neurovascul': 4523,
#  'quadripol': 5481,
#  'automa': 580,
#  'high': 3162,
#  'performanc': 4995,
#  'substituica': 6381,
#  'stery': 6329,
#  'recolocaca': 5611,
#  'zipw': 7433,
#  'epifisiodes': 2309,
#  'proxim': 5415,
#  'situ': 6142,
#  'planalt': 5124,
#  'endobasket': 2177,
#  "'frx": 1,
#  'otic': 4781,
#  'megabe': 4104,
#  'biolitec': 768,
#  'holmium': 3210,
#  'hbfsf': 3046,
#  'neuron': 4508,
#  'surgifl': 6448,
#  'powd': 5254,
#  'infect': 3364,
#  'plasm': 5130,
#  'spray': 6276,
#  'inserca': 3419,
#  'first': 2709,
#  'brit': 929,
#  'manifold': 3985,
#  'torn': 6731,
#  'peelaway': 4952,
#  'lock': 3884,
#  'recanalizaca': 5594,
#  'prim': 5312,
#  'circulatori': 1235,
#  'ortic': 4722,
#  'cupul': 1688,
#  'espondilolistes': 2414,
#  'anastomos': 278,
#  'autotransfusa': 591,
#  'quick': 5498,
#  'draw': 1997,
#  'eletrocirurg': 2099,
#  'poleg': 5183,
#  'subclav': 6362,
#  'vent': 7207,
#  'ureterolitotrips': 7108,
#  'sessa': 6038,
#  'tendril': 6576,
#  'cura': 1690,
#  'excet': 2536,
#  'queim': 5495,
#  'pump': 5449,
#  'agraft': 178,
#  'lipodistrof': 3854,
#  'braqu': 916,
#  'crur': 1674,
#  'trocanteri': 6942,
#  'superi': 6414,
#  'inferi': 3366,
#  'ades': 125,
#  'dermabond': 1797,
#  'viscos': 7300,
#  'xienc': 7388,
#  'intersoma': 3499,
#  'transforam': 6797,
#  'abert': 15,
#  'inlay': 3398,
#  'rupt': 5896,
#  'manguit': 3983,
#  'aortic': 369,
#  'articulaco': 468,
#  'kirschnn': 3675,
#  'ginecolog': 2932,
#  'cromotub': 1650,
#  'tunel': 6993,
#  'equip': 2335,
#  'extens': 2575,
#  'cicatriz': 1204,
#  'excisa': 2538,
#  'retalh': 5747,
#  'cutane': 1709,
#  'regia': 5656,
#  'expan': 2554,
#  'retangul': 5749,
#  'remot': 5687,
#  'lefort': 3771,
#  'realinh': 5583,
#  'aparelh': 372,
#  'exten': 2572,
#  'anel': 295,
#  'mitr': 4284,
#  'carpenti': 1083,
#  'edward': 2079,
#  'physi': 5074,
#  'admir': 133,
#  'xtrem': 7409,
#  'patel': 4916,
#  'patelectom': 4917,
#  'kirschin': 3672,
#  'barr': 667,
#  'transvers': 6850,
#  'octopu': 4621,
#  'estreit': 2478,
#  'percuflex': 4979,
#  'uromax': 7131,
#  'axxces': 620,
#  'diafis': 1856,
#  'bimaleol': 735,
#  'trimaleol': 6924,
#  'colecistostom': 1347,
#  'teflon': 6550,
#  'prob': 5322,
#  'litotr': 3868,
#  'arritmogen': 445,
#  'radiofrequenc': 5527,
#  'conj': 1483,
#  'cool': 1534,
#  'interject': 3480,
#  'multivalv': 4398,
#  'amigdalectom': 252,
#  'palatin': 4824,
#  'faring': 2630,
#  'endotraque': 2233,
#  'avanc': 596,
#  'granufo': 2978,
#  'pelicul': 4956,
#  'cole': 1343,
#  'timp': 6664,
#  'ttptm': 6981,
#  'variac': 7168,
#  'ajusta': 193,
#  'implantaca': 3302,
#  'radiocirurg': 5522,
#  'estimu': 2467,
#  'cranioplast': 1625,
#  'osteomielit': 4760,
#  'recobr': 5609,
#  'bioceram': 745,
#  'transl': 6806,
#  'coron': 1561,
#  'interefrenc': 3464,
#  'norm': 4555,
#  'frez': 2845,
#  'hidrocefal': 3146,
#  'piezosonic': 5092,
#  'lapidu': 3732,
#  'degrau': 1768,
#  'dissecca': 1947,
#  'along': 224,
#  'transport': 6833,
#  'pseudoartros': 5424,
#  'fixafi': 2725,
#  'coll': 1361,
#  'esteril': 2452,
#  'recobert': 5608,
#  'hydr': 3237,
#  'condili': 1452,
#  'bloqued': 860,
#  'kirschn': 3674,
#  'steinman': 6317,
#  'antimicrobi': 357,
#  'dors': 1988,
#  'escolios': 2366,
#  'cost': 1590,
#  'posicion': 5242,
#  'viscer': 7298,
#  'expres': 2570,
#  'cron': 1653,
#  'inveter': 3578,
#  'recidiv': 5603,
#  'costel': 1592,
#  'estern': 2457,
#  'chib': 1185,
#  'process': 5330,
#  'bern': 702,
#  'perfur': 4997,
#  'novation': 4563,
#  'organ': 4696,
#  'malformaca': 3962,
#  'mirag': 4279,
#  'needl': 4446,
#  'part': 4900,
#  'kitc': 3682,
#  'brizi': 930,
#  'vesic': 7256,
#  'bexig': 704,
#  'autorosque': 587,
#  'epimiocard': 2316,
#  ...}

# %%
word_count_vector.shape
# Out:
# (674719, 7440)

# %% [markdown]
# #### Get TF-IDF Vectors

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer(smooth_idf=True,use_idf=True)

# %%
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
tf_idf_vector = tfidf_transformer.transform(CV.transform(docs))

# %%
tf_idf_vector.shape
# Out:
# (674719, 7440)

# %% [markdown]
# #### Export TF-IDF Vectors

# %%
import scipy.sparse
scipy.sparse.save_npz("tfidf_vectors.npz", tf_idf_vector)
